# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    n=len(feature)
    distance=np.zeros(n)
    for i in range(n):
        distance[i] = np.linalg.norm(center-feature[i])

        
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    i=np.where(label_feature==label)
    centroid=np.mean(feature[i],axis=0)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return centroid

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    label_feature=np.argmin(distance,axis=0)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature

# %%
def compute_loss(center,feature,label_feature,number_cluster):
    loss=0
    for i in range(number_cluster):
        index=np.where(label_feature==i)
        loss=loss+compute_distance(feature[index],center[i]).sum()
    loss=loss/number_data
    return loss

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 30     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
distance=np.zeros((number_data,number_cluster))
centroid=np.zeros((number_cluster,number_feature))

index=np.random.randint(number_data,size=2)
centroid=feature[index,:]
label_cluster=np.arange(number_cluster)
for i in range(number_iteration):
    for k in range(len(label_cluster)):
        distance[:,k]=compute_distance(feature,centroid[k])
    label_feature_02=compute_label(distance)
    loss_iteration_02[i]=compute_loss(centroid,feature,label_feature_02,2)
    
    for s in range(len(label_cluster)):
        centroid[k]=compute_centroid(feature,label_feature_02,s)    
    centroid_iteration_02[i]=centroid
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Out:
# c:\Python38\lib\site-packages\numpy\core\fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Python38\lib\site-packages\numpy\core\_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 30     # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
distance=np.zeros((number_data,number_cluster))
centroid=np.zeros((number_cluster,2))

index=np.random.randint(number_data,size=4)
centroid=feature[index,:]
label_cluster=np.arange(number_cluster)
for i in range(number_iteration):
    for k in range(len(label_cluster)):
        distance[:,k]=compute_distance(feature,centroid[k])
    label_feature_04=compute_label(distance)
    loss_iteration_04[i]=compute_loss(centroid,feature,label_feature_04,4)
    
    for s in range(len(label_cluster)):
        centroid[k]=compute_centroid(feature,label_feature_04,s)
    centroid_iteration_04[i]=centroid

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 30     # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
distance=np.zeros((number_data,number_cluster))
centroid=np.zeros((number_cluster,2))

index=np.random.randint(number_data,size=8)
centroid=feature[index,:]
label_cluster=np.arange(number_cluster)
for i in range(number_iteration):
    for k in range(len(label_cluster)):
        distance[:,k]=compute_distance(feature,centroid[k])
    label_feature_08=compute_label(distance)
    loss_iteration_08[i]=compute_loss(centroid,feature,label_feature_08,8)
    
    for s in range(len(label_cluster)):
        centroid[k]=compute_centroid(feature,label_feature_08,s)
    centroid_iteration_08[i]=centroid

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 30    # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
distance=np.zeros((number_data,number_cluster))
centroid=np.zeros((number_cluster,2))

index=np.random.randint(number_data,size=16)
centroid=feature[index,:]
label_cluster=np.arange(number_cluster)
for i in range(number_iteration):
    for k in range(len(label_cluster)):
        distance[:,k]=compute_distance(feature,centroid[k])
    label_feature_16=compute_label(distance)
    loss_iteration_16[i]=compute_loss(centroid,feature,label_feature_16,16)
    
    for s in range(len(label_cluster)):
        centroid[k]=compute_centroid(feature,label_feature_16,s)
    centroid_iteration_16[i]=centroid

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.plot(centroid_iteration_02[:,:,0],centroid_iteration_02[:,:,1],'-')
    plt.plot(centroid_iteration_02[0,:,0],centroid_iteration_02[0,:,1],'o', color = 'blue')
    plt.plot(centroid_iteration_02[-1,:,0],centroid_iteration_02[-1,:,1],'s', color = 'red')
    labels = []
    for i in range(len(centroid_iteration_02[0,:,0])):
        labels.append('cluster = '+str(i))
    labels.append('initial')
    labels.append('final')
    
    plt.legend(labels)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.plot(centroid_iteration_04[:,:,0],centroid_iteration_04[:,:,1],'-')
    plt.plot(centroid_iteration_04[0,:,0],centroid_iteration_04[0,:,1],'o', color = 'blue')
    plt.plot(centroid_iteration_04[-1,:,0],centroid_iteration_04[-1,:,1],'s', color = 'red')
    labels = []
    for i in range(len(centroid_iteration_04[0,:,0])):
        labels.append('cluster = '+str(i))
    labels.append('initial')
    labels.append('final')
    
    plt.legend(labels)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.plot(centroid_iteration_08[:,:,0],centroid_iteration_08[:,:,1],'-')
    plt.plot(centroid_iteration_08[0,:,0],centroid_iteration_08[0,:,1],'o', color = 'blue')
    plt.plot(centroid_iteration_08[-1,:,0],centroid_iteration_08[-1,:,1],'s', color = 'red')
    labels = []
    for i in range(len(centroid_iteration_08[0,:,0])):
        labels.append('cluster = '+str(i))
    labels.append('initial')
    labels.append('final')
    
    plt.legend(labels)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    plt.plot(centroid_iteration_16[:,:,0],centroid_iteration_16[:,:,1],'-')
    plt.plot(centroid_iteration_16[0,:,0],centroid_iteration_16[0,:,1],'o', color = 'blue')
    plt.plot(centroid_iteration_16[-1,:,0],centroid_iteration_16[-1,:,1],'s', color = 'red')
    labels = []
    for i in range(len(centroid_iteration_16[0,:,0])):
        labels.append('cluster = '+str(i))
    labels.append('initial')
    labels.append('final')
    
    plt.legend(labels)

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) =  0.0039157994
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) =  0.0062103474
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) =  0.0194283298
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) =  0.0116910422
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# **************************************************
# **************************************************
# ## [RESULT 08]
# **************************************************
# **************************************************
# ## [RESULT 09]
# **************************************************
# **************************************************
# ## [RESULT 10]
# **************************************************
# **************************************************
# ## [RESULT 11]
# **************************************************
# **************************************************
# ## [RESULT 12]
# **************************************************
# **************************************************
# ## [RESULT 13]
# **************************************************
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Python38\lib\site-packages\matplotlib\axes\_axes.py:4221, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4219'>4220</a> try:  # Is 'c' acceptable as PathCollection facecolors?
# -> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4220'>4221</a>     colors = mcolors.to_rgba_array(c)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4221'>4222</a> except (TypeError, ValueError) as err:
#
# File c:\Python38\lib\site-packages\matplotlib\colors.py:377, in to_rgba_array(c, alpha)
#     <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=375'>376</a> else:
# --> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=376'>377</a>     rgba = np.array([to_rgba(cc) for cc in c])
#     <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=378'>379</a> if alpha is not None:
#
# File c:\Python38\lib\site-packages\matplotlib\colors.py:377, in <listcomp>(.0)
#     <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=375'>376</a> else:
# --> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=376'>377</a>     rgba = np.array([to_rgba(cc) for cc in c])
#     <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=378'>379</a> if alpha is not None:
#
# File c:\Python38\lib\site-packages\matplotlib\colors.py:187, in to_rgba(c, alpha)
#     <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=185'>186</a> if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=186'>187</a>     rgba = _to_rgba_no_colorcycle(c, alpha)
#     <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=187'>188</a>     try:
#
# File c:\Python38\lib\site-packages\matplotlib\colors.py:269, in _to_rgba_no_colorcycle(c, alpha)
#     <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=267'>268</a> if not np.iterable(c):
# --> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=268'>269</a>     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/colors.py?line=269'>270</a> if len(c) not in [3, 4]:
#
# ValueError: Invalid RGBA argument: 100.0
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\jimmy0505\01\assignment_11.ipynb Cell 53' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000051?line=7'>8</a> print(title)
#       <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000051?line=8'>9</a> print('**************************************************')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000051?line=9'>10</a> eval(name_function)
#
# File <string>:1, in <module>
#
# c:\Users\jimmy0505\01\assignment_11.ipynb Cell 44' in function_result_13()
#       <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000042?line=3'>4</a> plt.title('cluster (K=2)')
#       <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000042?line=5'>6</a> # ++++++++++++++++++++++++++++++++++++++++++++++++++
#       <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000042?line=6'>7</a> # complete the blanks
#       <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000042?line=7'>8</a> #
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000042?line=8'>9</a> scatter = plt.scatter(feature[:,0],feature[:,1], marker='o', c=label_feature_02, cmap=plt.cm.get_cmap('plasma', len(label_cluster)))
#      <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000042?line=10'>11</a> plt. axis('equal')
#      <a href='vscode-notebook-cell:/c%3A/Users/jimmy0505/01/assignment_11.ipynb#ch0000042?line=11'>12</a> handles, labels = scatter.legend_elements()
#
# File c:\Python38\lib\site-packages\matplotlib\pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2801'>2802</a> @_copy_docstring_and_deprecators(Axes.scatter)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2802'>2803</a> def scatter(
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2803'>2804</a>         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2804'>2805</a>         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2805'>2806</a>         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2806'>2807</a>     __ret = gca().scatter(
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2807'>2808</a>         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2808'>2809</a>         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2809'>2810</a>         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2810'>2811</a>         **({"data": data} if data is not None else {}), **kwargs)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2811'>2812</a>     sci(__ret)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/pyplot.py?line=2812'>2813</a>     return __ret
#
# File c:\Python38\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/__init__.py?line=1408'>1409</a> @functools.wraps(func)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/__init__.py?line=1409'>1410</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/__init__.py?line=1410'>1411</a>     if data is None:
# -> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/__init__.py?line=1411'>1412</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/__init__.py?line=1413'>1414</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/__init__.py?line=1414'>1415</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/__init__.py?line=1415'>1416</a>                   or bound.kwargs.get(label_namer))
#
# File c:\Python38\lib\site-packages\matplotlib\axes\_axes.py:4387, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4383'>4384</a> if edgecolors is None:
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4384'>4385</a>     orig_edgecolor = kwargs.get('edgecolor', None)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4385'>4386</a> c, colors, edgecolors = \
# -> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4386'>4387</a>     self._parse_scatter_color_args(
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4387'>4388</a>         c, edgecolors, kwargs, x.size,
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4388'>4389</a>         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4390'>4391</a> if plotnonfinite and colors is None:
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4391'>4392</a>     c = np.ma.masked_invalid(c)
#
# File c:\Python38\lib\site-packages\matplotlib\axes\_axes.py:4227, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4224'>4225</a> else:
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4225'>4226</a>     if not valid_shape:
# -> <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4226'>4227</a>         raise invalid_shape_exception(c.size, xsize) from err
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4227'>4228</a>     # Both the mapping *and* the RGBA conversion failed: pretty
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4228'>4229</a>     # severe failure => one may appreciate a verbose feedback.
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4229'>4230</a>     raise ValueError(
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4230'>4231</a>         f"'c' argument must be a color, a sequence of colors, "
#    <a href='file:///c%3A/Python38/lib/site-packages/matplotlib/axes/_axes.py?line=4231'>4232</a>         f"or a sequence of numbers, not {c}") from err
#
# ValueError: 'c' argument has 2 elements, which is inconsistent with 'x' and 'y' with size 1000.
